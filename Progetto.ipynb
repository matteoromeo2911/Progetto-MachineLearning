# %% [markdown]
# <h1>Progetto</h1>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import librosa.display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
music_data = pd.read_csv('Data/features_30_sec.csv') 
music_data.head(5)
# Out:
#           filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1  blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2  blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3  blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4  blues.00004.wav  661794          0.308526         0.087841  0.091529
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002827             1784.165850          129774.064525
# 1  0.002373             1530.176679          375850.073649
# 2  0.002746             1552.811865          156467.643368
# 3  0.006346             1070.106615          184355.942417
# 4  0.002303             1835.004266          343399.939274
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2002.449060            85882.761315  ...   52.420910
# ...

# %%
music_data['label'].value_counts()
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: count, dtype: int64

# %% [markdown]
# * path = 'Data/genres_original/blues/blues.00000.wav'  definisco il percorso audio
# * plt.figure(figsize=(14, 5)) Qui si crea una finestra di dimensioni 14x5 pollici (dimensioni in unità matplotlib) dove verrà visualizzato il grafico.
# * librosa.display.waveplot(x, sr=sr) Visualizza la forma d'onda del file audio con librosa.display.waveplot().
# - Carica il file audio usando librosa.load().

# %%
path = 'Data/genres_original/blues/blues.00000.wav'
plt.figure(figsize=(14, 2)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
  
print("Blue")
# Out:
# Blue

# %%
path = 'Data/genres_original/pop/pop.00000.wav'
plt.figure(figsize=(14,2)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr,color='purple') 

  
print("Pop")
# Out:
# Pop

# %%
path = 'Data/genres_original/metal/metal.00000.wav'
plt.figure(figsize=(14, 2)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr,color='orange') 
  
print("Metal")
# Out:
# Metal

# %% [markdown]
# spike_cols = [col for col in data.columns if 'mean' in col]
# Questa riga crea una lista di nomi di colonne da data (che presumibilmente è un DataFrame di Pandas) contenenti la stringa 'mean' nel loro nome. L'obiettivo è selezionare solo le colonne che hanno qualcosa a che fare con la media (ad esempio: mean_temperature, mean_pressure, ecc.).
#
# data.columns: recupera i nomi delle colonne del DataFrame.
# if 'mean' in col: filtra le colonne il cui nome contiene la stringa 'mean'.
# -------------
# f, ax = plt.subplots(figsize=(16, 11))
# Qui viene creata una figura (canvas) su cui disegnare il grafico, con plt.subplots(), che crea sia la figura (contenitore generale del grafico) che gli assi su cui disegnare. La dimensione della figura è impostata su 16x11 pollici con il parametro figsize=(16, 11), rendendo il grafico più grande e dettagliato.
#
# f: rappresenta l'oggetto della figura.
# ax: rappresenta gli assi su cui verrà disegnato il grafico.
# ---------------
# sns.heatmap(data[spike_cols].corr(), cmap='YlGn')
# sns.heatmap(): crea una heatmap per visualizzare la matrice di correlazione tra le colonne selezionate.
# data[spike_cols].corr(): calcola la matrice di correlazione tra le colonne selezionate. La correlazione indica quanto le colonne sono linearmente correlate tra loro (con valori che vanno da -1 a 1).
# cmap='YlGn': specifica la mappa di colori usata per la heatmap. YlGn significa "Yellow-Green" (giallo-verde), dove i valori più bassi sono rappresentati dal giallo e quelli più alti dal verde.
# --------------------
# plt.title('Heatmap for MEAN variables', fontsize = 20)
# plt.xticks(fontsize = 10)
# plt.yticks(fontsize = 10)
# plt.title(): imposta il titolo del grafico, in questo caso "Heatmap for MEAN variables", con una dimensione del carattere pari a 20.
# plt.xticks(fontsize=10) e plt.yticks(fontsize=10): riducono la dimensione del testo delle etichette sull'asse x e sull'asse y a 10, migliorando la leggibilità del grafico.
# ---------------
# Riepilogo del codice
# Crea una figura per visualizzare una heatmap di correlazione.
# Seleziona le colonne del dataset che contengono 'mean' nel nome.
# Calcola la matrice di correlazione tra queste colonne e la visualizza come heatmap, utilizzando una mappa di colori che va dal giallo al verde.
# Personalizza il titolo e le etichette degli assi per rendere il grafico più leggibile.

# %%
import numpy as np 
import seaborn as sns 
  
# Computing the Correlation Matrix 
spike_cols = [col for col in music_data.columns if 'mean' in col] 
  
# Set up the matplotlib figure 
f, ax = plt.subplots(figsize=(16, 11)); 
  
# Draw the heatmap with the mask and correct aspect ratio 
sns.heatmap(music_data[spike_cols].corr(), cmap='YlGn') 
  
plt.title('Heatmap for MEAN variables', fontsize = 20) 
plt.xticks(fontsize = 10) 
plt.yticks(fontsize = 10);

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
music_data['label'] = label_encoder.fit_transform(music_data['label'])

# %%
X = music_data.drop(['label','filename'],axis=1) 
y = music_data['label']

# %%
# Ora è necessario ridimensionare i dati per rendere il modello più stabile e velocizzarne l'addestramento.
cols = X.columns 
minmax = preprocessing.MinMaxScaler() 
np_scaled = minmax.fit_transform(X) 
  
# new data frame with the new scaled data.  
X = pd.DataFrame(np_scaled, columns = cols)

# %%
from sklearn.model_selection import train_test_split 
  
X_train, X_test, y_train, y_test = train_test_split(X, y,  
                                                    test_size=0.3,  
                                                    random_state=111) 
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 58), (300, 58), (700,), (300,))

# %%
from sklearn.metrics import accuracy_score 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression 
import catboost as cb 
from xgboost import XGBClassifier 
  
rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0) 
cbc = cb.CatBoostClassifier(verbose=0, eval_metric='Accuracy', loss_function='MultiClass') 
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05) 
  
for clf in (rf, cbc, xgb): 
    clf.fit(X_train, y_train) 
    preds = clf.predict(X_test) 
    print(clf.__class__.__name__,accuracy_score(y_test, preds))
# Out:
# RandomForestClassifier 0.78
# CatBoostClassifier 0.8333333333333334
# XGBClassifier 0.7833333333333333

# %%
logreg = LogisticRegression(solver='lbfgs', max_iter=1000)

# Addestrare il modello
logreg.fit(X_train, y_train)

# Fare previsioni sul set di test
y_pred = logreg.predict(X_test)

# Valutare il modello
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.67
